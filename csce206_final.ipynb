# %% [markdown]
# #CSCE 206 - Final exam - Fall 2022
#
# Oscillators are important in the study of many systems, mechanical, biological, chemical, electrical, and others. One such oscillator is known as the [Van der Pol oscillator](https://en.wikipedia.org/wiki/Van_der_Pol_oscillator) (relaxation oscillator). This system can be expressed in multiple equivalent ways, one of them being as a set of two differential equations
#
# $\dot x=\mu\left(x-\frac{1}{3}x^3 -y\right)$
#
# $\dot y =\frac{1}{\mu}x$
#
# Note that the variable $\mu$ is a parameter with a constant real value that changes the shape of the oscillations.
#
# Instructions: Create a class that can be used to simulate Van der Pol oscillators. That class should contain at least the following methods:
# - add_oscillator(self, mu, x0=1, y0=0) : Add a new oscillator with parameters $mu$ and initial values x(0)=x0 (default: 1) and y(0)=y0 (default: 0).
# - delete_oscillator(self, i): Delete the i-th oscillator from the list of available oscillators.
# - get_sim_data(self, duration=30.0, dt=0.01): Simulate the N oscillators previously added to the object (using `add_oscillator`) for the specified `duration` (default: 30s) and with a sampling step `dt` (default: 0.01s) and return the simulated data as a pandas DataFrame of shape (duration/dt, N). "Simulating" these oscillators mean obtaining `x(t)` by solving the ODE above. This can be done manually using the Euler integration scheme (as seen in previous labs) or using an ODE solver (e.g., scipy's solve_ivp function).
# - plot(self, tmin=0.0, tmax=30.0): Plot the time course of the different oscillators from `tmin` to `tmax`.
#
# Here is an example of use:
#
# ```python
# vdp = VanDerPol()
# vdp.add_oscillator(1.0) # oscillator 0
# vdp.add_oscillator(3.0) # oscillator 1
# vdp.add_oscillator(2.0) # oscillator 2
# vdp.delete_oscillator(1)
# print(vdp.get_sim_data(dt=0.01))
# vdp.plot(tmin=10)
# ```
#
# This code prints
# ```
#               0         1
# 0.00   1.000000  1.000000
# 0.01   1.006616  1.013282
# 0.02   1.013131  1.026455
# 0.03   1.019543  1.039513
# 0.04   1.025851  1.052445
# ...         ...       ...
# 29.95 -1.978776  2.020113
# 29.96 -1.975802  2.020557
# 29.97 -1.972716  2.020779
# 29.98 -1.969524  2.020792
# 29.99 -1.966229  2.020607
# ```
#
# and show the following figure:
#
# ![image.png](data:image/png;base64,...)
#
# As an indication, my solution takes about 50 lines.

# %%
########### INSERT YOUR CODE ###########

########################################

# %% [markdown]
# # Submission
#
# Please submit a .py file containing your answers in Blackbox. A simple way to generate such a .py file from a Colab Notebook is to click File --> Download --> Download .py. This .py file will need to be added as an attachment to your submission. **The deadline to submit the final is December 8th, 5 PM. There will be no extension. The final exam CAN NOT be done in teams; it is an individual assignment. Plagiarism or failure to submit in time will result in 0%. You will be granted unlimited submission attempts up to the due date and time. Be sure to submit well in advance to avoid bad surprises (e.g., computer issues right before the deadline). Since you are allowed unlimited submission, it is safe to submit a partial answer well in advance and refine your solution later (but before the deadline).**
